# %%
# %pip uninstall -y google-auth-oauthlib google-auth-httplib2 google-auth google-api-python-client
# %pip install --upgrade google-auth-oauthlib==0.4.1 google-auth-httplib2 google-auth==2.27.0 google-api-python-client
# Out:
# Found existing installation: google-auth-oauthlib 1.2.1
# Uninstalling google-auth-oauthlib-1.2.1:
#   Successfully uninstalled google-auth-oauthlib-1.2.1
# Found existing installation: google-auth-httplib2 0.2.0
# Uninstalling google-auth-httplib2-0.2.0:
#   Successfully uninstalled google-auth-httplib2-0.2.0
# Found existing installation: google-auth 2.30.0
# Uninstalling google-auth-2.30.0:
#   Successfully uninstalled google-auth-2.30.0
# Found existing installation: google-api-python-client 2.148.0
# Uninstalling google-api-python-client-2.148.0:
#   Successfully uninstalled google-api-python-client-2.148.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting google-auth-oauthlib==0.4.1
#   Downloading google_auth_oauthlib-0.4.1-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting google-auth-httplib2
#   Using cached google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting google-auth==2.27.0
#   Downloading google_auth-2.27.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: google-api-python-client in c:\miniconda3\lib\site-packages (2.143.0)
# Collecting google-api-python-client
#   Downloading google_api_python_client-2.153.0-py2.py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\nathan adhitya\appdata\roaming\python\python312\site-packages (from google-auth-oauthlib==0.4.1) (2.0.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\miniconda3\lib\site-packages (from google-auth==2.27.0) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\nathan adhitya\appdata\roaming\python\python312\site-packages (from google-auth==2.27.0) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\miniconda3\lib\site-packages (from google-auth==2.27.0) (4.9)
# Requirement already satisfied: httplib2>=0.19.0 in c:\miniconda3\lib\site-packages (from google-auth-httplib2) (0.22.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\nathan adhitya\appdata\roaming\python\python312\site-packages (from google-api-python-client) (2.19.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\miniconda3\lib\site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\nathan adhitya\appdata\roaming\python\python312\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.63.2)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in c:\miniconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (5.28.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\nathan adhitya\appdata\roaming\python\python312\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.24.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\miniconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.32.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\nathan adhitya\appdata\roaming\python\python312\site-packages (from httplib2>=0.19.0->google-auth-httplib2) (3.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\miniconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth==2.27.0) (0.6.0)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib==0.4.1)
#   Downloading oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nathan adhitya\appdata\roaming\python\python312\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nathan adhitya\appdata\roaming\python\python312\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nathan adhitya\appdata\roaming\python\python312\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nathan adhitya\appdata\roaming\python\python312\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2024.2.2)
# Downloading google_auth_oauthlib-0.4.1-py2.py3-none-any.whl (18 kB)
# Downloading google_auth-2.27.0-py2.py3-none-any.whl (186 kB)
#    ---------------------------------------- 0.0/186.8 kB ? eta -:--:--
#    ------ -------------------------------- 30.7/186.8 kB 660.6 kB/s eta 0:00:01
#    ------------ -------------------------- 61.4/186.8 kB 825.8 kB/s eta 0:00:01
#    ------------------------------------- -- 174.1/186.8 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 186.8/186.8 kB 1.3 MB/s eta 0:00:00
# Using cached google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Downloading google_api_python_client-2.153.0-py2.py3-none-any.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/12.6 MB 4.3 MB/s eta 0:00:03
#    - -------------------------------------- 0.5/12.6 MB 5.6 MB/s eta 0:00:03
#    -- ------------------------------------- 0.8/12.6 MB 6.4 MB/s eta 0:00:02
#    -- ------------------------------------- 0.8/12.6 MB 6.4 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.5/12.6 MB 7.1 MB/s eta 0:00:02
#    ------ --------------------------------- 2.1/12.6 MB 8.2 MB/s eta 0:00:02
#    ------- -------------------------------- 2.3/12.6 MB 7.4 MB/s eta 0:00:02
#    ------- -------------------------------- 2.3/12.6 MB 7.1 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.2/12.6 MB 7.9 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.2/12.6 MB 7.9 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.2/12.6 MB 7.9 MB/s eta 0:00:02
#    --------------- ------------------------ 5.0/12.6 MB 9.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.2/12.6 MB 9.3 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.5/12.6 MB 8.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.5/12.6 MB 8.7 MB/s eta 0:00:01
#    --------------------- ------------------ 6.8/12.6 MB 9.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.3/12.6 MB 9.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.3/12.6 MB 9.5 MB/s eta 0:00:01
#    ------------------------- -------------- 7.9/12.6 MB 9.4 MB/s eta 0:00:01
#    ------------------------- -------------- 8.0/12.6 MB 8.9 MB/s eta 0:00:01
#    -------------------------- ------------- 8.4/12.6 MB 8.7 MB/s eta 0:00:01
#    ------------------------------ --------- 9.7/12.6 MB 9.6 MB/s eta 0:00:01
#    -------------------------------- ------- 10.2/12.6 MB 9.7 MB/s eta 0:00:01
#    -------------------------------- ------- 10.2/12.6 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.8/12.6 MB 10.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.3/12.6 MB 10.6 MB/s eta 0:00:01
#    ------------------------------------ --- 11.6/12.6 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------  12.4/12.6 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 10.4 MB/s eta 0:00:00
# Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#    ---------------------------------------- 0.0/151.7 kB ? eta -:--:--
#    ------------------------------------- -- 143.4/151.7 kB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 151.7/151.7 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: oauthlib, google-auth, google-auth-oauthlib, google-auth-httplib2, google-api-python-client
#   Attempting uninstall: google-api-python-client
#     Found existing installation: google-api-python-client 2.143.0
#     Uninstalling google-api-python-client-2.143.0:
#       Successfully uninstalled google-api-python-client-2.143.0
# Successfully installed google-api-python-client-2.153.0 google-auth-2.27.0 google-auth-httplib2-0.2.0 google-auth-oauthlib-0.4.1 oauthlib-3.2.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import base64
import re
import pandas as pd

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
